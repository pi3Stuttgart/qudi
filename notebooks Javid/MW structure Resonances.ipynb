# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from scipy import optimize

# %%
x1 = np.linspace(2,3,21)
x2 = np.linspace(2.68,2.8,13)
x2
# Out:
# array([2.68, 2.69, 2.7 , 2.71, 2.72, 2.73, 2.74, 2.75, 2.76, 2.77, 2.78,
#        2.79, 2.8 ])

# %%
y1 = np.array([109,
               109.3,
               107.4,
               107.7,
               107.7,
               107.7,
               108.1,
               108.1,
               108.4,
               108.7,
               109.5,
               109.5,
               111.3,
               111.5,
               112.6,
               118.3,
               116.7,
               110.5,
               110.3,
               109.3,
               108.2    
])

# %%
y2 = np.array([114,
               113.7,
               112.7,
               112.8,
               113.8,
               116.2,
               119.2,
               118.3,
               115.8,
               114.1,
               114.2,
               115.4,
               116.7               
    
])

# %%
plt.plot(x1,-y1)
plt.show()

# %%
plt.plot(x2,-y2)
plt.show()

# %%
plt.plot(x1,-y1,'o',color = 'black')
plt.plot(x2,-y2,'o',color = 'black')

plt.show()
