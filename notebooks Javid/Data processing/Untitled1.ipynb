# %%
import matplotlib
from numpy import *
# %matplotlib notebook
from matplotlib import pyplot as plt
y1 = lambda B: abs(2870-2.8*B)
y2 = lambda B: abs(2870+2.8*B)
plt.figure(dpi=150)
B = linspace(0,2000,1000)
plt.plot(B,y1(B))
plt.plot(B,y2(B))
plt.fill_between([B[0],B[-1]],[1000,1000],[3300,3300],alpha=0.2)
plt.fill_between([460,540],[1000,1000],[3300,3300],color = 'r',alpha=0.2)
plt.fill_between([900,1100],[1000,1000],[3300,3300],color = 'r',alpha=0.2)
#plt.fill_between([B[0],B[-1]],[1000,1000],[3300,3300],alpha=0.2)
# plt.ylim(3500,4500)
# plt.xlim(0,1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="958.8889142907702">

# %%
import matplotlib.pyplot as plt
import numpy as np
import datetime
import matplotlib.dates as mdates
from matplotlib.transforms import Transform
from matplotlib.ticker import (
    AutoLocator, AutoMinorLocator)

fig, ax = plt.subplots(constrained_layout=True)
x = np.arange(0, 360, 1)
y = np.sin(2 * x * np.pi / 180)
ax.plot(x, y)
ax.set_xlabel('angle [degrees]')
ax.set_ylabel('signal')
ax.set_title('Sine wave')


def deg2rad(x):
    return x * np.pi / 180


def rad2deg(x):
    return x * 180 / np.pi

secax = ax.secondary_xaxis('top', functions=(deg2rad, rad2deg))
secax.set_xlabel('angle [rad]')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-5d23e21d12ff> in <module>()
#      23     return x * 180 / np.pi
#      24
# ---> 25 secax = ax.secondary_xaxis('top', functions=(deg2rad, rad2deg))
#      26 secax.set_xlabel('angle [rad]')
#      27 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'secondary_xaxis'

# %%
matplotlib.__version__
# Out:
# '2.2.2'
